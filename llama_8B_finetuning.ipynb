# %%
##### RAG NEW VERSION ##############
import os
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import SKLearnVectorStore
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community0.document_loaders import PyPDFLoader
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
from langchain.chains import LLMChain
from langchain_community.llms import HuggingFacePipeline
import re
import torch
from transformers import AutoModelForCausalLM
import numpy as np

# %%
import transformers
transformers.__version__

# %%
def load_llama_model():
    device = 'cuda'
    model_id = "/home/hice1/dbabu6/scratch/Llama-3.1-8B-Instruct" 
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.bfloat16, device_map="auto")
    return pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=256, temperature = 0.2)

# %%
LLM = load_llama_model()

# %%
torch.cuda.is_available()

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=250, chunk_overlap=0)

# %%
file_path = "/home/hice1/dbabu6/scratch/pdf_files/PDF_Syllabus_Dataset"
def load_documents():
    docs = []
    for file in os.listdir(file_path):
        if file.endswith(".pdf"):
            try:
                loader = PyPDFLoader(os.path.join(file_path, file))
                pdf_docs = loader.load()
                docs.extend(pdf_docs)
                # logger.info(f"Loaded document: {file}")
            except Exception as e:
                continue
                # logger.error(f"Error loading {file}: {e}")
    # logger.info(f"Total documents loaded: {len(docs)}")
    return docs
docs = load_documents()

# %%
doc_splits = text_splitter.split_documents(docs)

# %%
### setting up the prompt template ###
prompt = PromptTemplate(
    template="""You are an assistant for question-answering tasks based on course content of Georgia Tech ECE department.
    Use the following documents to answer the question.
    Use five sentences maximum and keep the answer concise:
    Question: {question}
    Documents: {documents}
    Answer:
    """,
    input_variables=["question", "documents"],
)

# %%
#### initialize the embedding model #### 

model_name = "BAAI/bge-base-en"
encode_kwargs = {'normalize_embeddings' : True}
model_norm = HuggingFaceBgeEmbeddings(model_name= model_name,
model_kwargs = {'device' : 'cuda'}, encode_kwargs = encode_kwargs)

#### initializing the vectorstore ####
vectorstore = SKLearnVectorStore.from_documents(
    documents=doc_splits,
    embedding=model_norm,
)
retriever = vectorstore.as_retriever(k=3)

# %%
# Create an LLM wrapper for your Hugging Face pipeline
llm = HuggingFacePipeline(pipeline=LLM)

# %%
# rag_chain = prompt | LLM | StrOutputParser()

# %%
# Create the LLMChain
rag_chain = LLMChain(llm=llm, prompt=prompt)

# %%
class RAGapplication():
    def __init__(self, retriever, rag_chain):
        self.retriever = retriever
        self.rag_chain = rag_chain

    def run(self, question):
        docs = self.retriever.invoke(question)
        docs_texts = "\n".join([str(n.page_content) for n in docs])
        # print(docs_texts)
        input_data = {
            "question": str(question),
            "documents": docs_texts
        }
        answer = self.rag_chain.invoke(input_data)
        return answer

# %%
rag_app = RAGapplication(retriever = retriever, rag_chain = rag_chain)

# %%
answer = rag_app.run('what is the the course content for ECE 6250')

# %%
ans= answer['text']

# %%
def extract_answer(text):
    answer_start = text.find("Answer:")
    if answer_start == -1:
        return "Answer not found."
    answer = text[answer_start + len("Answer:"):].strip()
    return answer
ans_processed = extract_answer(ans)

# %%
print(ans_processed, end ='\n')

# %%
# !pip install accelerate peft bitsandbytes trl

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Installing More Dependencies
import torch
from datasets import load_dataset, Dataset
from peft import LoraConfig, AutoPeftModelForCausalLM
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
from trl import SFTTrainer
import os

# %%
model_id="/home/hice1/dbabu6/scratch/Llama-3.1-8B-Instruct"

# %%
def get_model_and_tokenizer(model_id):
  tokenizer = AutoTokenizer.from_pretrained(model_id)
  tokenizer.pad_token = tokenizer.eos_token
  bnb_config = BitsAndBytesConfig(
      load_in_4bit=True, bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype="float16", bnb_4bit_use_double_quant=True
  )
  model = AutoModelForCausalLM.from_pretrained(
      model_id, quantization_config=bnb_config, device_map="auto"
  )
  model.config.use_cache=False
  model.config.pretraining_tp=1
  return model, tokenizer

# %%
model, tokenizer = get_model_and_tokenizer(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
##### running an inference ######
from transformers import GenerationConfig
from time import perf_counter
def generate_response(user_input):
  prompt = formatted_prompt(user_input)
  print(prompt)
  inputs = tokenizer([prompt], return_tensors="pt")
  generation_config = GenerationConfig(penalty_alpha=0.6,do_sample = True,
      top_k=5,temperature=0.5,repetition_penalty=1.2,
      max_new_tokens=60,pad_token_id=tokenizer.eos_token_id
  )
  start_time = perf_counter()
  inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
  outputs = model.generate(**inputs, generation_config=generation_config)
  theresponse = (tokenizer.decode(outputs[0], skip_special_tokens=True))
  print(tokenizer.decode(outputs[0], skip_special_tokens=True))
  output_time = perf_counter() - start_time
  print(f"Time taken for inference: {round(output_time,2)} seconds")

# %%
def formatted_prompt(question)-> str:
    return f"<|im_start|>user\n{question}<|im_end|>\n<|im_start|>assistant:"

# %%
generate_response(user_input='What is Georgia Tech? How good it is?')

# %%
#### preparing the dataset #####

import pandas as pd
def load_qa_pairs(data_path):
    data = pd.read_csv(data_path, encoding = "latin-1")
    return data

# %%
data_path = "/home/hice1/dbabu6/scratch/Query_Response_Pairs_ConvAI_Project(Sheet1) (1).csv"
data = load_qa_pairs(data_path)

# %%
training_data = [{"prompt": prompt, "response": response} for prompt, response in zip(data['Query'], data['Response'])]

# %%
training_data
# Out:
# [{'prompt': 'What is the main focus of the ECE 8803 HOS (High-dimensional statistics, signal processing, and optimization) course?',
#   'response': 'The main focus of ECE 8803 HOS is high-dimensional statistics and optimization. The course introduces students to modern analyses of one-shot and iterative algorithms in high-dimensional statistical learning and signal processing. It covers analytical tools from probability and optimization, analyzes M-estimators and iterative methods in statistical models, and introduces convex relaxation and its analysis'},
#  {'prompt': 'Who is the instructor for ECE 8803 HOS?',
#   'response': 'The instructor for ECE 8803 HOS is Ashwin Pananjady. He is a faculty member with a joint appointment between ISyE and ECE at Georgia Tech. Ashwin received his Ph.D. in EECS from UC Berkeley and spent a semester as a postdoctoral research fellow at the Simons Institute for the Theory of Computing'},
#  {'prompt': 'What are the key learning outcomes of ECE 8803 HOS?',
#   'response': 'Upon successful completion of ECE 8803 HOS, students will have learned:\n(a) A variety of modern algorithms for high-dimensional data analysis problems\n(b) Several ways to model and exploit structure in high dimensions\n(c) The design principles of convex relaxation and iterative optimization\n(d) Several analysis tools from optimization and probability, including dual witness techniques and Gaussian process theory, to prove rigorous guarantees on modern methods'},
#  {'prompt': 'What are the prerequisites for ECE 8803 HOS?',
#   'response': 'Prerequisites for ECE 8803 HOS include a solid knowledge of undergraduate probability and statistics, linear algebra, multivariable calculus, and basic optimization. The most important prerequisite is mathematical maturity and familiarity with understanding and writing proofs'},
#  {'prompt': 'How is ECE 8803 HOS graded?',
#   'response': 'ECE 8803 HOS is graded on the following components:\nHomework (50%): 4-5 assignments, each with 3-5 questions\nMidterm (20%): A tentative take-home midterm active for 48 hours\nCourse project (30%): An in-depth study of a topic related to the course'},
#  {'prompt': 'What is the policy on collaboration for homework assignments in ECE 8803 HOS?',
#   'response': 'In ECE 8803 HOS, students are strongly encouraged to discuss homework problems with one another. However, each student must write up and turn in their own solutions, written in their own words or consisting of their own code. Cases where written solutions or code appear to be identical or nearly identical will be immediately referred to the Office of Student Integrity'},
#  {'prompt': 'What are the options for the course project in ECE 8803 HOS?',
#   'response': 'The course project for ECE 8803 HOS can take one of the following forms:\nAn in-depth survey of a topic covered in class\nAn application of algorithms discussed in class on a dataset or engineering application\nA conceptual (theoretical or simulation-based) topic of novel research related to the class\nProjects can be done in groups of up to two students'},
#  {'prompt': 'What resources are recommended for ECE 8803 HOS?',
#   'response': 'While there is no single required textbook for ECE 8803 HOS, some helpful resources include:\n"High-Dimensional Statistics: A Non-Asymptotic Viewpoint" by Martin Wainwright\n"High-Dimensional Probability: An Introduction with Applications in Data Science" by Roman Vershynin\n"Spectral Methods for Data Science: A Statistical Viewpoint" by Yuxin Chen, Yueijie Chi, Jianqing Fan and Cong Ma\n"Convex Optimization: Algorithms and Complexity" by Sebastien Bubeck'},
#  {'prompt': 'What are the main topics covered in Part I of ECE 8803 HOS?',
#   'response': 'Part I of ECE 8803 HOS covers the analysis of convex optimization for statistical learning problems, including:\nConcentration inequalities for scalar random variables\nConcentration properties of random matrices and applications\nSparse linear models in high dimensions\nGeometric properties of convex relaxation\nExact error analysis using Gaussian processes'},
#  {'prompt': 'What communication platforms are used for ECE 8803 HOS?',
#   'response': 'ECE 8803 HOS uses Canvas to maintain course materials, including general course information, supplementary reading materials, and homework assignments. Piazza is used exclusively for announcements, answering questions, and fostering discussion about problems'},
#  {'prompt': ' How are homework assignments structured in ECE 8803 HOS?',
#   'response': 'ECE 8803 HOS includes 4-5 homework assignments, each containing 3-5 questions. Homework is typically assigned once every three weeks, with deadlines usually on Wednesdays. Students are given a total of 6 late days to use throughout the semester, which can be applied to any homework assignments. Solutions are released 7 days after the deadline, and students are required to self-grade their work. They must submit a detailed self-grade on Canvas one week after the solutions are released. '},
#  {'prompt': 'When and where is ECE 8803 ALT held?',
#   'response': 'ECE 8803 ALT is held on Mondays and Wednesdays from 1400-1515 in 2456 Klaus Advanced Computing'},
#  {'prompt': 'Who is the instructor for ECE 8803 ALT, and what are their office hours?',
#   'response': 'The instructor for ECE 8803 ALT is Dr. Suman Datta, who holds the Joseph M Pettit Chair in Advanced Computing and is a Professor of Electrical and Computer Engineering at Georgia Institute of Technology. His office hours are on Wednesdays from 1700-1850 in Klaus 2360'},
#  {'prompt': 'What are the main objectives of ECE 8803 ALT?',
#   'response': 'The main objectives of ECE 8803 ALT include developing a fundamental understanding of scattering limited transport versus ballistic transport of carriers in modern semiconductor devices, quantitatively analyzing the electrostatic robustness in ultra-scaled MOS transistors, and introducing students to mechanisms that limit modern transistor performance'},
#  {'prompt': 'How is ECE 8803 ALT graded, and what is the expected grade distribution?',
#   'response': 'ECE 8803 ALT is graded based on homework (50%, 5 problem sets worth 10% each), a midterm exam (25%), and a final exam (25%). The expected grade distribution is: A (85+), B (70+), C (55+), D (40+), and F (<40)'},
#  {'prompt': 'What are the references for ECE 8803 ALT?',
#   'response': ' While there is no official textbook required for ECE 8803 ALT, two optional references are provided:\n"Electronic Transport in Mesoscopic Systems" by S. Datta\n"Nanoscale Transistors: Device Physics, Modeling and Simulation" by Mark Lundstrom and Jing Guo, published by Springer'},
#  {'prompt': 'What is the late submission policy for homework in ECE 8803 ALT?',
#   'response': 'In ECE 8803 ALT, late homework submissions are penalized as follows:\nOne day late: 80% of the original score\nTwo days late: 50% of the original score\nThree or more days late: No score given'},
#  {'prompt': 'How should homework be submitted in ECE 8803 ALT?',
#   'response': 'For ECE 8803 ALT, homework should be submitted as electronically scanned versions of the completed assignments'},
#  {'prompt': 'What is the policy on questioning homework or exam grading in ECE 8803 ALT?',
#   'response': ' In ECE 8803 ALT, any questions regarding homework or exam grading must be asked within one week after the homework or exam is returned to the students'},
#  {'prompt': 'What is the absence policy for ECE 8803 ALT?',
#   'response': ' ECE 8803 ALT follows the Institute absence policy as detailed at http://www.catalog.gatech.edu/rules/4/. Students are expected to adhere to this policy for any absences from class'},
#  {'prompt': 'What are some of the main topics covered in the course outline of ECE 8803 ALT?',
#   'response': 'ECE 8803 ALT covers topics such as electron dynamics, off-equilibrium transport in devices, ballistic and quantum ballistic transport, collision-dominated transport, extremely scaled MOSFETs, and includes projects analyzing nanoscale devices (e.g., 10nm node commercial FinFETs)'},
#  {'prompt': 'What is the grading breakdown for ECE 8893?',
#   'response': 'The grading for ECE 8893 is divided as follows: Lab Assignments (30%, 3 labs at 10% each), Paper Presentation (10%), and Project (60%, broken down into proposal 10%, mid-term report 5%, source code 15%, presentation 10%, and final report 20%).'},
#  {'prompt': 'Who is the instructor for ECE 8893: Parallel Programming for FPGAs?',
#   'response': 'The instructor for ECE 8893 is Cong (Callie) Hao.'},
#  {'prompt': 'What are some examples of FPGA cloud services mentioned in the course description of ECE 8893?',
#   'response': "ECE 8893 mentions several FPGA cloud services, including Amazon's AWS with F1 FPGA clusters, Microsoft Azure FPGA cloud, and Xilinx's FPGA adaptive compute cluster at multiple universities."},
#  {'prompt': 'What software tools will be used in ECE 8893 for FPGA programming?',
#   'response': 'In ECE 8893, students will use Vivado for FPGA programming tutorials and Vitis HLS for High-Level Synthesis.'},
#  {'prompt': 'How does ECE 8893 address the topic of Software/Hardware Co-design?',
#   'response': 'ECE 8893 covers Software/Hardware Co-design by focusing on hardware-aware algorithm design and neural architecture search.'},
#  {'prompt': ' What types of neural networks are specifically mentioned in the syllabus of ECE 8893?',
#   'response': ' The syllabus for ECE 8893 specifically mentions Deep Neural Networks (DNNs) and Graph Neural Networks (GNNs).'},
#  {'prompt': 'What are some of the FPGA design techniques covered in ECE 8893?',
#   'response': 'ECE 8893 covers FPGA design techniques such as data precision and model quantization, loop optimizations, array partitioning, data reuse, model tiling, storage and memory access optimization, and data streaming.'},
#  {'prompt': 'How does ECE 8893 incorporate recent research into the curriculum?',
#   'response': 'ECE 8893 incorporates recent research by including papers from recent FPGA, computer architecture, and machine learning conferences such as ISCA, MICRO, HPCA, ASPLOS, DATE, DAC, ICCAD, ICCD, ICML, NeurIPS, ICLR, and CVPR.'},
#  {'prompt': 'What is the attendance policy for ECE 8893?',
#   'response': 'For ECE 8893, students are expected to attend all lectures and exams. In case of a documented emergency or university-mandated reason, students should contact the instructor before or at the latest by the day of the exam.'},
#  {'prompt': 'How does ECE 8893 address learning accommodations for students with disabilities?',
#   'response': 'ECE 8893 will make classroom accommodations for students with disabilities. These accommodations should be arranged in advance and in accordance with the office of Disability Services.'},
#  {'prompt': ' What is the policy on academic integrity in ECE 8893?',
#   'response': 'ECE 8893 follows the Georgia Tech Academic Honor Code. Students are expected to exhibit honest and ethical behavior. All assignments must be done individually unless explicitly stated otherwise, and incidents of suspected dishonesty will be reported to the office of student affairs.'},
#  {'prompt': 'What future trends in FPGA technology are discussed in ECE 8893?',
#   'response': 'ECE 8893 covers future trends in FPGA technology, including spatial temporal GNNs, scientific computing, and analog accelerators.'},
#  {'prompt': 'How does the project component of ECE 8893 relate to the course content?',
#   'response': 'The semester-long project in ECE 8893 focuses on developing an FPGA accelerator using High-Level Synthesis (HLS) for Deep Neural Network (DNN) or Graph Neural Network (GNN) algorithms, directly applying the course content to a practical implementation.'},
#  {'prompt': 'What is the significance of C/RTL Co-simulation in ECE 8893?',
#   'response': ' C/RTL Co-simulation is covered in ECE 8893 as part of the FPGA Design Techniques, allowing students to verify and debug their high-level C/C++ designs against the generated Register-Transfer Level (RTL) implementation.'},
#  {'prompt': 'Who is the primary instructor for ECE 8803 EV?',
#   'response': 'The primary instructor for ECE 8803 EV is Maryam Saeedifard, a Professor in the School of ECE.'},
#  {'prompt': 'When and where are the lectures for ECE 8803 EV held?',
#   'response': 'ECE 8803 EV lectures are held on Mondays and Wednesdays from 11:00 am to 12:15 pm in the Clough UG Learning Commons.'},
#  {'prompt': 'What are the main topics covered in ECE 8803 EV?',
#   'response': 'ECE 8803 EV covers various aspects of Electric Vehicles, including vehicle architectures, electrical components, their integration into vehicle transmission systems, vehicle power management, grid integration issues, drivetrains, energy storage, electromechanical energy conversion, power electronics, vehicle-level modeling and control, and safety optimization.'},
#  {'prompt': 'What are the prerequisites for undergraduate students taking ECE 8803 EV?',
#   'response': 'Undergraduate students must have taken or be concurrently taking ECE 4330 to enroll in ECE 8803 EV.'},
#  {'prompt': 'How is the grading structured for ECE 8803 EV?',
#   'response': 'The grading for ECE 8803 EV is structured as follows: Homework assignments (50%), Midterm exam (20%), Final Exam (30% for undergraduate students and 20% for graduate students), and Final Project (10% for graduate students only).'},
#  {'prompt': 'How many homework assignments are there in ECE 8803 EV?',
#   'response': 'There are 5 homework assignments throughout the course of ECE 8803 EV.'},
#  {'prompt': 'What is the late submission policy for assignments in ECE 8803 EV?',
#   'response': ' In ECE 8803 EV, late assignments will be penalized by 2% per day, with a maximum of 3 days allowed for overdue submissions.'},
#  {'prompt': ' How does ECE 8803 EV accommodate online students?',
#   'response': 'For online students in ECE 8803 EV, all assignment due dates and exam dates will be shifted by one week compared to on-campus students.'},
#  {'prompt': 'What are the office hours for the instructor of ECE 8803 EV?',
#   'response': 'The office hours for the instructor, Maryam Saeedifard, are on Tuesdays from 11:30 am to 12:30 pm in Van Leer building room E168, starting from Week 2.\n'},
#  {'prompt': 'Who is the primary instructor for ECE 8804 VLSI Design 1?',
#   'response': 'The primary instructor for ECE 8804 VLSI Design 1 is Visvesh Sathe.'},
#  {'prompt': 'What is the main focus of ECE 8804 VLSI Design 1?',
#   'response': 'ECE 8804 VLSI Design 1 focuses on a comprehensive VLSI design experience involving theory, design, verification, and test of a fabricated CMOS digital VLSI design. The centerpiece of the course is a semester-long effort by student teams to produce quality designs that will be fabricated in an industry standard CMOS process.'},
#  {'prompt': 'What are the learning outcomes for ECE 8804 VLSI Design 1?',
#   'response': 'Upon successful completion of ECE 8804 VLSI Design 1, students should be able to:\nTranslate digital design specifications into concise, synthesizable hardware descriptions using System Verilog.\nEffectively use industry-standard synthesis, place-and-route (SAPR), and verification tools to implement large designs.\nDevelop effective judgment in scoping minimum working examples (MWE) for trailblazing unknown processes.\nEffectively scope and partition design construction, flow development, validation, and test of hardware designs as part of a team effort.\nDesign hardware modules for silicon prototyping, successful testing, characterization, and validation.'},
#  {'prompt': 'What are the prerequisites for ECE 8804 VLSI Design 1?',
#   'response': 'The sole prerequisite for ECE 8804 VLSI Design 1 is ECE3150. Students should be comfortable with basic command-line Linux usage and have basic familiarity with the Verilog Hardware Description Language (HDL) for FPGA implementation.'},
#  {'prompt': 'How is the grading structured for ECE 8804 VLSI Design 1?',
#   'response': "The grading for ECE 8804 VLSI Design 1 is structured as follows:\n8 10-minute quizzes (best 5 count towards the final grade): 10%\nIndividual homework assignments: 10%\nTeam homework assignments: 10%\nCourse participation: 10%\nFinal project work: 50%\nBonus credits may be offered at the instructor's discretion."},
#  {'prompt': 'What is the policy on collaboration and group work in ECE 8804 VLSI Design 1?',
#   'response': 'For ECE 8804 VLSI Design 1, students are strongly encouraged to discuss homework problem strategies and related concepts with one another. However, each student must formulate and turn in their own solutions written in their own words. Cases where scripts, programs, design descriptions, or any relevant material appear to be identical or nearly identical will be immediately referred to the Office of Student Integrity.'},
#  {'prompt': 'How does ECE 8804 VLSI Design 1 address the use of generative AI tools?',
#   'response': 'ECE 8804 VLSI Design 1 welcomes the use of generative AI tools in design. Students are encouraged to share strategies that allow for more effective production, verification, or analysis of designs. However, students must clearly cite the use of AI technology in any written or verbal report, and no special consideration will be given to errors arising from the use of generative AI unless explicitly agreed upon with the instructor.'},
#  {'prompt': 'What are the office hours for the instructor of ECE 8804 VLSI Design 1?',
#   'response': 'The instructor for ECE 8804 VLSI Design 1, Visvesh Sathe, will hold two office hours per week. The specific days are to be determined (TBD). If a teaching assistant (TA) is assigned to the course, they will offer 4 office hours per week. If no TA is assigned, the instructor will increase their office hours to 4 per week. Additionally, the course offers "workout" sessions on specific weekends at critical junctures to help students make progress on their projects.\n'},
#  {'prompt': 'can you generate a question for course outline for the ECE 8804 course?\n\n\n',
#   'response': " The course outline for ECE 8804 VLSI Design 1 covers a wide range of topics related to VLSI design, including:\nTiming analysis for flip-flops and latches from a designer's perspective\nPipelining and parallel processing\nSynthesis, Auto-place and Route from a designer's perspective\nMemories (SRAM, DRAM, ROM) from a designer's perspective\nDesign construction strategies (trailblazing, minimum working examples)\nSystem Verilog overview\nLogical and physical interconnect (wires, buses)\nBasic Verification methodologies and techniques\nCrossing clock and voltage domains (FIFOs metastability and synchronization)\nRobustly Resetting large digital systems\nDesign for Test (BIST, Scan)\nDesign for Manufacturability (EM, IR)\nClock generation and distribution basics (PLLs, DLLs, distribution structures)\nProcess, Voltage and Temperature Variability (OCV, AOCV)"},
#  {'prompt': " What is the course's policy on late assignments for ECE 8804 VLSI Design 1?",
#   'response': 'In ECE 8804 VLSI Design 1, late homeworks will be aggressively penalized. This policy is designed to maintain a regular cadence toward project completion and to avoid projects spiraling out of control, rather than serving as a punitive grade-discrimination mechanism.'},
#  {'prompt': 'Who is the instructor for ECE 6607?',
#   'response': 'The instructor for ECE 6607 is Prof. Min Luo.'},
#  {'prompt': 'What is the required textbook for ECE 6607?',
#   'response': 'The required textbook for ECE 6607 is Computer Networking: A top-down approach featuring the Internet by Kurose and Ross, 7th edition, Pearson, 2017.'},
#  {'prompt': 'How is the final grade calculated for ECE 6607?',
#   'response': 'The final grade for ECE 6607 is calculated as follows: 30% Midterm, 40% Final, 25% Homework, and 5% Class Participation.'},
#  {'prompt': 'What are the prerequisites for ECE 6607?',
#   'response': 'The prerequisites for ECE 6607 are a basic understanding of computer systems and proficiency in programming in C/C++/Java/Python.'},
#  {'prompt': 'What is the grading scale for ECE 6607?',
#   'response': 'The grading scale for ECE 6607 is as follows:\nA: 90-100%\nB: 80-89%\nC: 70-79%\nD: 60-69%\nF: 0-59%'},
#  {'prompt': 'How does the instructor handle attendance and participation in ECE 6607?',
#   'response': 'In ECE 6607, the instructor observes and records incidents of inattention, which can seriously impact the Homework/Attendance/Participation portion of the grade.'},
#  {'prompt': 'What are the main topics covered in ECE 6607?',
#   'response': 'The main topics covered in ECE 6607 include:\n1. Introduction to Networks and Internet\n2. Application layer\n3. Transport layer\n4. Network layer - Data Plane\n5. Network layer - Control Plane\n6. Link layer and LAN\n7. Wireless and mobile networks\n8. Security\n9. Multimedia networking'},
#  {'prompt': 'What is the policy on late assignments in ECE 6607?',
#   'response': 'For ECE 6607, no late homework will be accepted without prior approval and arrangements.'},
#  {'prompt': 'How are exams handled if a student has an unexpected event in ECE 6607?',
#   'response': 'In ECE 6607, exams can be rescheduled if students have to deal with unexpected events, but this requires pre-approval from the instructor.'},
#  {'prompt': 'What is the course duration and schedule for ECE 6607?',
#   'response': 'ECE 6607 runs from August 19, 2019 to November 1, 2019, with classes held on Mondays and Wednesdays from 9:30-11:30 (though the exact time and classroom are marked with question marks in the syllabus).'},
#  {'prompt': 'What is the course number for Analog Integrated Circuit Design?',
#   'response': 'The course number is ECE 6412'},
#  {'prompt': 'Who is the instructor for ECE 6412?',
#   'response': 'The instructor is Prof. Gabriel A. Rincón-Mora, Ph.D'},
#  {'prompt': 'When and where are the lectures for ECE 6412 held?',
#   'response': 'The lectures are held on Tuesdays and Thursdays from 5:00-6:15 p.m. in Van Leer C456'},
#  {'prompt': 'What are the main topics covered in ECE 6412?',
#   'response': 'The main topics covered include analog electronics, analog primitives, feedback, differential stage, operational amplifiers, linear voltage regulators, comparators, and reference circuits'},
#  {'prompt': 'How is the final grade composed for ECE 6412?',
#   'response': 'The final grade is composed of 30% for the Midterm Exam, 35% for the Final Exam, 30% for Assignments, and 5% for Class Attendance/Professionalism'},
#  {'prompt': 'Is class attendance important for ECE 6412?',
#   'response': 'Yes, class attendance is important. It accounts for 5% of the final grade under Class Attendance/Professionalism'},
#  {'prompt': 'What is the prerequisite for ECE 6412?',
#   'response': 'The prerequisite is ECE 4430 Analog Integrated Circuits or equivalent'},
#  {'prompt': 'Are late assignment submissions allowed in ECE 6412?',
#   'response': 'Late submissions are not allowed without prior approval. If approved, they lose 20% for each day they are late, including weekends'},
#  {'prompt': 'What is the policy on using electronic devices during lectures in ECE 6412?',
#   'response': 'Cellular phones, laptops, and tablets must be turned off and kept out of sight during lectures'},
#  {'prompt': 'What textbook is used for ECE 6412?',
#   'response': 'The main textbook is Analog IC Design, 8th Edition published by KDP'},
#  {'prompt': 'What is the course number for Regression Analysis?',
#   'response': 'The course number is ISYE 6414.'},
#  {'prompt': 'Who is the instructor for ISYE 6414?',
#   'response': 'The instructor is Gamze Tokol-Goldsman.'},
#  {'prompt': 'What are the main topics covered in ISYE 6414?',
#   'response': 'The main topics covered include Simple Linear Regression, ANOVA, Multiple Linear Regression, Logistic and Poisson Regression, and Other Regression Methods and Case Studies.'},
#  {'prompt': 'How many midterm exams are there in ISYE 6414?',
#   'response': 'There are two midterm exams in ISYE 6414.'},
#  {'prompt': 'What is the weightage for homework assignments in ISYE 6414?',
#   'response': 'Homework assignments account for 20% of the total grade.'},
#  {'prompt': 'Is there a final exam for ISYE 6414?',
#   'response': 'No, there is no final exam for ISYE 6414.'},
#  {'prompt': 'What is the weightage for the project in ISYE 6414?',
#   'response': 'The project accounts for 20% of the total grade.'},
#  {'prompt': 'When are the midterm exams scheduled for ISYE 6414?',
#   'response': 'Midterm Exam 1 is scheduled for Wednesday, October 4, and Midterm Exam 2 is scheduled for Wednesday, November 15.'},
#  {'prompt': 'Is attendance mandatory for ISYE 6414?',
#   'response': 'The syllabus does not explicitly state that attendance is mandatory. However, it mentions that if students are sick or have symptoms of an infectious disease, they should not attend class, and efforts will be made to record lectures for those who miss them.'},
#  {'prompt': 'What software will be used in ISYE 6414?',
#   'response': 'The course will involve computer programming in R.'},
#  {'prompt': 'Who is the instructor for ECE 6453?',
#   'response': 'The instructor is Prof. Paul Yoder'},
#  {'prompt': 'What is the course number and title for the graduate-level electronic devices course?',
#   'response': 'The course number is ECE6453, and the title is Theory of Electronic Devices'},
#  {'prompt': 'How many credit hours does ECE6453 carry?',
#   'response': 'ECE6453 is a 3-credit hour course, as indicated by the notation (3-0-0-3)'},
#  {'prompt': 'What is the prerequisite for ECE6453?',
#   'response': 'The prerequisite for ECE6453 is ECE 6451'},
#  {'prompt': 'Which technical interest group or course type does ECE6453 fall under?',
#   'response': ' ECE6453 falls under the Nanotechnology technical interest group'},
#  {'prompt': 'What are the main topics covered in ECE6453?',
#   'response': 'The main topics covered in ECE6453 are:\n1.  Electronic Device Physics\n2. Field Effect Transistors\n3. Bipolar transistors'},
#  {'prompt': 'Can you list some specific subtopics covered under Electronic Device Physics in ECE6453?',
#   'response': 'Under Electronic Device Physics, ECE6453 covers:\nAdvanced p-n junction analysis\n1. MOS analysis\n2. Metal semiconductor contacts\n3. Breakdown-tunneling and impact ionization\n4. Field effect\n5. Ambipolar transport\n6. Heterojunction formation and analysis\n7. Modulation doping'},
#  {'prompt': 'What types of field effect transistors are studied in ECE6453?',
#   'response': 'ECE6453 covers the following types of field effect transistors:\n1. JFET\n2. MESFET\n3. MOSFET\n4. HEMT'},
#  {'prompt': 'Are there any lab hours associated with ECE6453?',
#   'response': 'No, ECE6453 does not have any lab hours. The course structure is listed as (3-0-0-3), indicating 0 supervised lab hours and 0 unsupervised lab hours'},
#  {'prompt': 'What are the strategic performance indicators (SPIs) for ECE6453?',
#   'response': 'The SPIs for ECE6453 include:\n1. Demonstrating understanding of the influence of materials and geometry on the electrical characteristics of field effect and bipolar devices\n2. Assessing the dependence of band diagrams, electrostatic potential and electric field as a function of bias condition for field effect and bipolar devices\n3. Constructing small-signal equivalent circuit models for field effect and bipolar devices to assess relevant electrical figures of merit'},
#  {'prompt': 'Is ECE6453 applicable for CMPE or EE degrees?',
#   'response': 'ECE6453 is not applicable for either the CMPE (Computer Engineering) or EE (Electrical Engineering) degrees'},
#  {'prompt': 'What is the course number for Bayesian Statistics at Georgia Tech?',
#   'response': 'The course number is ISyE 6420.'},
#  {'prompt': 'Who is the instructor for ISyE 6420?',
#   'response': 'The instructor is Dr. Roshan Joseph, Professor.'},
#  {'prompt': 'What is the delivery method for ISyE 6420?',
#   'response': 'The course is delivered 100% web-based and asynchronous.'},
#  {'prompt': 'What are the prerequisites for ISyE 6420?',
#   'response': 'The prerequisites are an introductory course in Probability and Statistics, basic programming proficiency, and Calculus.'},
#  {'prompt': 'How is the final grade calculated in ISyE 6420?',
#   'response': 'The final grade is calculated as a weighted average with Homeworks constituting 30%, Midterm 25%, Project 10%, and Final 35% of the total.'},
#  {'prompt': 'How many homework assignments are there in ISyE 6420?',
#   'response': 'There are 6 homework assignments in the course.'},
#  {'prompt': 'Is attendance mandatory for ISyE 6420?',
#   'response': 'As this is a fully online course, physical attendance is not required. However, students are expected to login regularly to complete their work.'},
#  {'prompt': 'What statistical software is used in ISyE 6420?',
#   'response': 'The course relies on WinBUGS and OpenBUGS software for Bayesian analysis.'},
#  {'prompt': 'What is the grading scale for ISyE 6420?',
#   'response': 'The grading scale is: A (90-100%), B (80-89%), C (70-79%), D (60-69%), and F (0-59%).'},
#  {'prompt': 'Is collaboration allowed among students in ISyE 6420?',
#   'response': 'Collaboration among students is encouraged, but each student should submit their individual work.'},
#  {'prompt': 'What is the course number for the graduate level class on sensors and actuators?',
#   'response': 'The course number is ECE6422.'},
#  {'prompt': 'Who is the instructor for ECE6422?',
#   'response': 'The instructor for ECE6422 is Professor Farrokh Ayazi.'},
#  {'prompt': 'What are the main topics covered in ECE6422?',
#   'response': 'The main topics covered in ECE6422 include:\n1. Integrated Sensors and Actuators: An Overview\n2. Transducers and Micro-Electro-Mechanical-System (MEMS) Devices\n3. Interface Circuits for MEMS and Sensors\n4. MEMS Oscillators'},
#  {'prompt': 'How is the final grade calculated for ECE6422?',
#   'response': 'The final grade for ECE6422 is calculated as follows:\n1. Homework: 40%\n2. Midterm exam: 25%\n3. Final exam: 35%\nAdditionally, there is an optional term paper worth 15% bonus points towards the final grade.'},
#  {'prompt': 'What are the prerequisites for taking ECE6422?',
#   'response': 'The prerequisites for ECE6422 are ECE 4430 (Analog Integrated Circuit Design I) or permission from Professor Ayazi. Students are also expected to be able to use HSPICE in Cadence for classroom assignments.'},
#  {'prompt': 'What simulation tools are used in ECE6422?',
#   'response': 'The simulation tools used in ECE6422 are COMSOL and CADENCE.'},
#  {'prompt': 'When are the office hours for ECE6422?',
#   'response': 'The office hours for ECE6422 are on Wednesdays from 1:00-2:00 PM in TSRB 512.'},
#  {'prompt': 'What is the grading scale for ECE6422?',
#   'response': 'The grading scale for ECE6422 is:\nA (>80), B (70-80), C (60-70), D (50-60), F (<50).'},
#  {'prompt': 'Is there an attendance policy mentioned in the syllabus for ECE6422?',
#   'response': 'The syllabus does not explicitly mention an attendance policy for ECE6422.'},
#  {'prompt': ' When is the final exam scheduled for ECE6422?',
#   'response': 'The final exam for ECE6422 is scheduled for Thursday, December 9, from 2:40 PM to 5:30 PM.'},
#  {'prompt': 'What is the full course number and title for ECE 6435?',
#   'response': 'The full course number and title is ECE 6435: Neuromorphic Analog VLSI Circuits.'},
#  {'prompt': 'Who is the instructor for ECE 6435?',
#   'response': 'ECE 6435 is taught by Professor Jennifer Hasler.'},
#  {'prompt': 'What are the main objectives of ECE 6435?',
#   'response': 'The main objectives of ECE 6435 are:\n1. To understand analog circuit design and computational neuroscience\n2. To understand the historical background of neuromorphic and physical computing systems\n3. To design neuromorphic and physical computing circuits and systems\n4. To critically evaluate current and past neuromorphic computing efforts'},
#  {'prompt': 'How is the final grade calculated in ECE 6435?',
#   'response': 'In ECE 6435, the final grade is based on 70% from design projects and 30% from a final paper or project.'},
#  {'prompt': 'What is the attendance policy for ECE 6435?',
#   'response': 'For ECE 6435, students are responsible for all material covered in class, including changes in project schedules announced in class. The syllabus states that skipping class or not paying attention correlates with poor performance, while attending and paying attention correlates with higher grades.'},
#  {'prompt': 'What are the prerequisite requirements for ECE 6435?',
#   'response': 'ECE 6435 assumes some basic knowledge of transistor circuits (e.g. ECE 3400 and/or ECE 4430 or equivalent) and fluency in spoken and written English.'},
#  {'prompt': 'How are the design projects structured in ECE 6435?',
#   'response': 'In ECE 6435, design projects are done in groups of two and involve experiments on custom VLSI chips, specifically Field Programmable Analog Arrays (FPAA). Projects include analytical problems, design problems, and experimental measurements.'},
#  {'prompt': 'What is required for the final project in ECE 6435?',
#   'response': 'For ECE 6435, the final project can be either a design project (done in a group) or a final paper critically analyzing an area of physical computing / neuromorphic engineering (done individually).'},
#  {'prompt': 'What software tools are required for ECE 6435?',
#   'response': 'ECE 6435 requires students to have VirtualBox and a provided Ubuntu virtual machine. The course uses Scilab/Scicos/Xcos for data analysis, though MATLAB is acceptable for final plots.'},
#  {'prompt': 'What is the format for project submissions in ECE 6435?',
#   'response': 'For ECE 6435, project writeups must be in two-column IEEE format, submitted as a PDF file, with a 9-page limit including references and figures. Data figures must be integrated into the text, not added at the end.'},
#  {'prompt': 'What is the course number for the graduate level course Silicon-Based Heterostructure Devices and Circuits?',
#   'response': 'The course number for this course is ECE 6444 .'},
#  {'prompt': 'Who is the instructor for ECE 6444?',
#   'response': 'The instructor is Dr. John D. Cressler.'},
#  {'prompt': 'When and where is ECE 6444 held?',
#   'response': 'The course is held on Tuesdays and Thursdays from 1:30-2:45pm in Gugg[AE] room 246.'},
#  {'prompt': 'What are the prerequisites for ECE 6444?',
#   'response': 'The prerequisites are a modest background in semiconductor devices. Undergraduates are welcome.'},
#  {'prompt': 'What are the main topics covered in ECE 6444?',
#   'response': 'The main topics include: Introduction, Epitaxial SiGe Alloys, The SiGe Heterojunction Bipolar Transistor, Circuit Design with SiGe HBTs, Other SiGe Heterostructure Devices, and Future Directions.'},
#  {'prompt': 'How many chapters does the course syllabus for ECE 6444 contain?',
#   'response': 'The course syllabus contains 8 chapters, numbered from Chapter 0 to Chapter 7.'},
#  {'prompt': 'What is covered in Chapter 0 of ECE 6444?',
#   'response': 'Chapter 0 covers Getting Up to Speed topics including reminders on semiconductor physics, BJTs vs FETs, the ideal BJT, the non-ideal BJT, and the generalized Moll-Ross relations.'},
#  {'prompt': 'What textbook is used for the assigned readings in ECE 6444?',
#   'response': "The assigned readings are from Cressler's book, with sections denoted as C x.x in the syllabus."},
#  {'prompt': 'What topics are covered in Chapter 6 of ECE 6444?',
#   'response': 'Chapter 6 covers Noise and Linearity, including fundamental considerations, broadband noise, low-frequency noise, profile design tradeoffs in noise, and linearity issues.'},
#  {'prompt': 'What additional topics might be covered in ECE 6444 if time permits?',
#   'response': 'Chapter 7 lists additional topics that may be covered if time permits, including temperature effects, radiation effects, strained-Si CMOS, and other types of Si-based devices.'},
#  {'prompt': 'Who is the instructor for ECE 8803 ECS?',
#   'response': 'The instructor for ECE 8803 ECS is Prof. Frank Li.\n'},
#  {'prompt': 'When and where are the lectures for ECE 8803 ECS held?',
#   'response': 'ECE 8803 ECS lectures are held on Tuesdays and Thursdays from 2:00 PM to 3:15 PM in Van Leer C340.'},
#  {'prompt': 'What are the prerequisites for ECE 8803 ECS?',
#   'response': 'The prerequisites for ECE 8803 ECS include familiarity with core computer security and computer networking concepts. Expected courses include ECE 4410/CS 4251 (Internetwork Programming/Computer Networking) and ECE 4115/CS 4235 (Introduction to Computer Security/Information Security) or their equivalents.'},
#  {'prompt': 'What is the main focus of ECE 8803 ECS?',
#   'response': 'ECE 8803 ECS focuses on empirical security research, which seeks to understand how computer security concerns manifest in practice. The course covers both classic and recent empirical security studies across various topics, including Internet security, underground ecosystems, usable security, and online privacy.'},
#  {'prompt': 'How is the grading structured for ECE 8803 ECS?',
#   'response': 'The grading for ECE 8803 ECS is structured as follows:\nParticipation: 20%\nDiscussion Lead: 10%\nPaper Summaries (written): 20%\nFinal Project: 50% (divided into Proposal 10%, Presentation 10%, and Writeup 30%)'},
#  {'prompt': 'What are the learning outcomes for ECE 8803 ECS?',
#   'response': "Upon completion of ECE 8803 ECS, students should be able to:\nRecognize how theory and empiricism complement each other in computer security research\nIdentify limitations or shortcomings in empirical security methodologies\nEngage in critical discussion around key research topics in computer security\nWrite and present a paper conforming to the security research community's standards\nPropose sound and rigorous measurement methodologies for open-ended research problems"},
#  {'prompt': 'What is the format of the final project in ECE 8803 ECS?',
#   'response': 'The final project in ECE 8803 ECS is a semester-long research project conducted in groups of 2-4 students. It includes a project proposal, a project presentation, and a final writeup in the form of a research-style paper.'},
#  {'prompt': 'How many paper summaries are required for ECE 8803 ECS?',
#   'response': ' For ECE 8803 ECS, students are required to submit brief paper summaries, analyses, and questions for each assigned paper. However, students are allowed to skip 2 summaries during the semester, or 3 if they lead a discussion solo.'},
#  {'prompt': 'What is the policy on collaboration in ECE 8803 ECS?',
#   'response': 'In ECE 8803 ECS, discussion about papers in groups is allowed and encouraged within reason, but paper summaries should be written and submitted separately by each student. Final projects can be done in groups of 2-4 people, depending on class size.'},
#  {'prompt': 'What is the grading scale used in ECE 8803 ECS?',
#   'response': 'The grading scale for ECE 8803 ECS is as follows:\nA: 90-100%\nB: 80-89%\nC: 70-79%\nD: 60-69%\nF: 0-59%\nThe course will not be graded on a curve.'},
#  {'prompt': 'Is there a required textbook for ECE 8803 ECS?',
#   'response': 'There is no required textbook for ECE 8803 ECS. The course relies on openly available reading materials and papers that will be compiled and made available on Canvas. For optional supplemental reading, the instructor recommends "Introduction to Computer Security" by Michael T. Goodrich and Roberto Tamassia, Addition Wesley, 2011.'},
#  {'prompt': 'Who is the primary instructor for ECE 8803 GGAI?',
#   'response': 'The primary instructor for ECE 8803 GGAI is Prof. Amirali Aghazadeh.\n'},
#  {'prompt': 'When and where are the lectures for ECE 8803 GGAI held?',
#   'response': 'ECE 8803 GGAI lectures are held on Tuesdays and Thursdays from 12:30-1:45 pm in Klaus 2447.'},
#  {'prompt': 'What are the prerequisites for ECE 8803 GGAI?',
#   'response': 'The main prerequisite for ECE 8803 GGAI is an advanced course in machine learning (ECE 6254, ECE 4252/8803 or equivalent). Students must also have Python and PyTorch programming expertise to train advanced deep-learning models.'},
#  {'prompt': 'What is the main objective of ECE 8803 GGAI?',
#   'response': 'The main objective of ECE 8803 GGAI is to cover the design, foundation, and applications of generative and geometric deep learning models with a special emphasis on large language models.'},
#  {'prompt': 'Are there required textbooks for ECE 8803 GGAI?',
#   'response': 'There are no required textbooks for ECE 8803 GGAI. However, the course recommends three excellent references: "Understanding Deep Learning" by Simon Prince, "Geometric Deep Learning: Grids, Groups, Graphs, Geodesics, and Gauges" by Bronstein et al., and "Deep Generative Models Course Notes" from Stanford by Stephano Ermon.'},
#  {'prompt': 'How is the grading structured for ECE 8803 GGAI?',
#   'response': 'The exact grading breakdown for ECE 8803 GGAI is to be determined (TBD). However, it will include homework assignments, exams, and a final project. The course will follow at least the basic traditional grading scale where A=90-100, B=80-89, C=70-79, D=60-69, F=0-59.'},
#  {'prompt': 'What type of assignments can students expect in ECE 8803 GGAI?',
#   'response': 'Assignments in ECE 8803 GGAI will have both an analytical part and a hands-on part. The hands-on parts are coding assignments, which will look like mini projects. Students may be asked to add to existing codes, write codes from scratch, search the literature for codes for specific applications, or summarize papers in the literature.'},
#  {'prompt': 'What programming languages and tools will be used in ECE 8803 GGAI?',
#   'response': ' ECE 8803 GGAI will utilize Python throughout the course. The class will also use a library of Jupyter notebooks, including Google Colab and PyTorch.'},
#  {'prompt': 'What online platforms will be used for course management in ECE 8803 GGAI?',
#   'response': ' ECE 8803 GGAI will use Canvas as the course website and Piazza for discussion and classwide communication.'},
#  {'prompt': 'Who is the instructor for ECE 8803 BFA?',
#   'response': 'The instructor for ECE 8803 BFA is Seun Sangodoyin.'},
#  {'prompt': ' What are the main objectives of ECE 8803 BFA?',
#   'response': ' The main objectives of ECE 8803 BFA are to educate students about the concept of bioelectromagnetics and its various applications, including: (i) bioelectric, biomagnetics and bioelectromagnetics phenomena in biological tissues, (ii) applying numerical methods for bioelectromagnetic simulation, (iii) characterizing electromagnetic wave propagation in multilayered heterogeneous tissues layers, and (iv) designing state-of-the-art measurement and stimulation systems for various clinical applications.'},
#  {'prompt': 'What are the learning outcomes for ECE 8803 BFA?',
#   'response': 'Upon successful completion of ECE 8803 BFA, students will be able to:\nDefine and provide examples of the fundamentals of bioelectromagnetics\nExplain the generation, characterization, and relationship between bioelectric, biomagnetic and bioelectromagnetic phenomena in biological tissues\nApply appropriate numerical methods for bioelectromagnetic simulation\nDesign stimulation and recording probes (electrodes) used in medical applications of bioelectromagnetics\nIdentify and explain the circumstances for various medical applications of bioelectromagnetics'},
#  {'prompt': 'What are the prerequisites for ECE 8803 BFA?',
#   'response': 'The prerequisites for ECE 8803 BFA are ECE 2040 [min C], ECE 3025 [min C], and ECE 4784 [min C] or BMED 4784 [min C]. No prior knowledge of physiology or biology is needed.'},
#  {'prompt': 'How is the grading structured for ECE 8803 BFA?',
#   'response': 'The grading for ECE 8803 BFA is structured as follows:\nHomework: 20%\n2 Exams: 40%\nFinal Project Proposal: 15%\nFinal Project Write-Up: 25%'},
#  {'prompt': 'Are there required textbooks for ECE 8803 BFA?',
#   'response': 'There are no required textbooks for ECE 8803 BFA. However, the course recommends two textbooks:\nPlonsey & Malmivuo, Bioelectromagnetism, Oxford University Press, 1995.\nC. Furse, D.A Christensen, C.H. Durney, and J. Nagel, "Basic Introduction to Bioelectromagnetics," CRC Press (3rd Ed), 2018.'},
#  {'prompt': 'What types of assignments can students expect in ECE 8803 BFA?',
#   'response': 'Students in ECE 8803 BFA can expect weekly homework assignments, two in-class exams, and a final project. The final project involves proposing a research project related to bioelectromagnetics, presenting it to the class, and providing a project write-up.'},
#  {'prompt': 'What topics are covered in the syllabus of ECE 8803 BFA?',
#   'response': 'The syllabus for ECE 8803 BFA covers a wide range of topics, including:\nIntroduction to Bioelectromagnetics\nReview of Electromagnetics\nNumerical Methods for Bioelectromagnetic Simulation\nAnatomical and Physiological concepts in Bioelectromagnetics\nBioelectromagnetics at Different Frequencies\nBioelectromagnetics for Clinical Applications\nNeuromodulation System Design'},
#  {'prompt': 'Who is the instructor for ECE 8803 AWN?',
#   'response': 'The instructor for ECE 8803 AWN is Karthikeyan Sundaresan.'},
#  {'prompt': 'When and where are the lectures for ECE 8803 AWN held?',
#   'response': 'ECE 8803 AWN lectures are held on Tuesdays and Thursdays from 2:00 PM to 3:15 PM in Van Leer.'},
#  {'prompt': 'What are the prerequisites for ECE 8803 AWN?',
#   'response': 'The recommended prerequisites for ECE 8803 AWN are ECE 4607 or ECE 6610 or ECE 6607 or any equivalent course in computer or wireless communication/networks. Basic knowledge of communication and wireless networks, along with an introductory background in wireless communications, is recommended.'},
#  {'prompt': 'What are the main objectives of ECE 8803 AWN?',
#   'response': 'The main objectives of ECE 8803 AWN are to educate and inform students on various advanced topics in wireless networking research, building upon fundamental concepts and focusing on challenges in designing and deploying large-scale wireless networks that can keep up with exponentially growing demands from application traffic.'},
#  {'prompt': 'How is the grading structured for ECE 8803 AWN?',
#   'response': 'The grading for ECE 8803 AWN is structured as follows:\nProgramming assignments (2): 20%\nMid-term: 25%\nResearch paper presentations (2): 15%\nFinal project: 30%\nPeer evaluation & class participation: 10%'},
#  {'prompt': 'Are there required textbooks for ECE 8803 AWN?',
#   'response': 'There are no required textbooks for ECE 8803 AWN. Research papers will be made available on Canvas, and experimental devices relevant for final projects will be provided.'},
#  {'prompt': 'What online platforms will be used for course management in ECE 8803 AWN?',
#   'response': 'ECE 8803 AWN will use Canvas as the course website.'},
#  {'prompt': 'What are some of the key topics covered in ECE 8803 AWN?',
#   'response': ' ECE 8803 AWN covers topics such as asynchronous and synchronous access networks, smart antenna networking, dynamic spectrum access, SDN in wireless, wireless and mobile sensing, low-power wireless networking, and wireless and autonomous platforms.'},
#  {'prompt': 'What is the policy on collaboration and group work in ECE 8803 AWN?',
#   'response': "In ECE 8803 AWN, most of the graded components will involve a group/team effort. While the group will be graded jointly, if there are significant differences in the amount of contribution of team members, appropriate relative grades may be assigned at the instructor's discretion. Students are allowed to refer to online resources, articles, and project codes for assignments and projects, but should not replicate them as is and should cite references appropriately."},
#  {'prompt': 'What is the course number for the graduate level course on Power Integrated Circuit Design?',
#   'response': 'The course number is ECE 6445.'},
#  {'prompt': 'Who is the instructor for ECE 6445?',
#   'response': 'The instructor is Prof. Gabriel A. Rincón-Mora, Ph.D.'},
#  {'prompt': 'When and where are the lectures for ECE 6445 held?',
# ...
#  {'prompt': 'How is the grading structured for ECE 8803 WPS?',
#   'response': 'The grading for ECE 8803 WPS is structured as follows:\nHomework: 20%\nMidterm Quizzes (2): 40%\nFinal Project: 40%'},
#  {'prompt': 'What are the official course goals and outcomes for ECE 8803 WPS?',
#   'response': 'The official course goals and outcomes for ECE 8803 WPS include:\nDescribing methods and trade-offs for transferring wireless energy between two points in space\nCalculating link parameters and power levels for different types of wireless energy systems\nDescribing how RF and microwave signals are generated\nDescribing the power consumption of various radio architectures and their trade-offs\nDesigning basic circuits that harvest and convert RF power and provide charge management\nDesigning a basic backscatter communications link\nDescribing and calculating attributes of a wireless power beaming link'},
#  {'prompt': 'Is there a required textbook for ECE 8803 WPS?',
#   'response': 'There is no formal required textbook for ECE 8803 WPS. Notes and papers for reading will be disseminated through T-square, and video captures of topical lectures are available on the YouTube channel [profdurgin].'},
#  {'prompt': 'What are some recommended reference books for ECE 8803 WPS?',
#   'response': 'Recommended references for ECE 8803 WPS include:\n"Wireless Power Transfer via Radiowaves" by N. Shinohara\n"The RF in RFID" (2nd edition) by D. Dobkin'},
#  {'prompt': 'What is the policy on late submissions for assignments in ECE 8803 WPS?',
#   'response': 'For ECE 8803 WPS, late work is not accepted. However, special accommodations can be made for medical emergencies, interviewing, and other important events, but only if sufficient advance notice is given to (and permission granted by) the instructor ahead of time.'},
#  {'prompt': 'How does ECE 8803 WPS address the use of mobile devices in class?',
#   'response': 'In ECE 8803 WPS, students may not use mobile devices during tests other than as calculators. Observations of violations during test periods will be reported to the Office of Student Integrity.'},
#  {'prompt': 'What is the policy on collaboration and group work in ECE 8803 WPS?',
#   'response': " For ECE 8803 WPS, discussion of topics and concepts are encouraged among students provided all submitted work is still original. Everyone must turn in their own work (or group's work where specified) without contribution from another person or source, whether homework, project, or test."},
#  {'prompt': 'Who is the instructor for ECE 8803 ODM?',
#   'response': ' The instructor for ECE 8803 ODM is Vidya Muthukumar.'},
#  {'prompt': 'What are the prerequisites for ECE 8803 ODM?',
#   'response': 'The prerequisites for ECE 8803 ODM are:\nAn introductory course in linear algebra and multivariable calculus (MATH2551 or equivalent)\nAn upper-division probability course (ECE3077 or equivalent)\nBasic Python programming skills (CS1301 or equivalent)\nAdditionally, prior background in optimization (ECE3xxx or equivalent) is recommended but not mandatory.'},
#  {'prompt': ' How is the grading structured for ECE 8803 ODM?',
#   'response': 'The grading for ECE 8803 ODM is structured as follows:\nHomeworks (45%)\nMidterm exam (25%)\nFinal Project (30%)\nFor graduate students, the final project is broken down into proposal (10%), presentation (10%), and final report (20%).'},
#  {'prompt': 'What are the main topics covered in ECE 8803 ODM?',
#   'response': 'ECE 8803 ODM covers four main parts:\nI. Online learning and optimization\nII. Multi-armed bandits\nIII. Reinforcement learning (RL)\nIV. Game theory/multi-agent systems\nNote: The instructor may choose to cover only one of Parts III and IV depending on student progress and understanding of material.'},
#  {'prompt': 'What is the policy on collaboration for homework assignments in ECE 8803 ODM?',
#   'response': 'For ECE 8803 ODM, students are strongly encouraged to discuss homework problem strategies and related concepts with one another. However, each student must formulate and turn in their own solutions written in their own words. Cases where solutions appear to be identical or nearly identical will be immediately referred to the Office of Student Integrity.'},
#  {'prompt': "What is the course's policy on the use of generative AI tools in ECE 8803 ODM?",
#   'response': ': ECE 8803 ODM welcomes the use of generative AI tools in design. Students are encouraged to share strategies that allow for more effective production, verification, or analysis of designs. However, students must clearly cite the use of AI technology in any written or verbal report, and no special consideration will be given to errors arising from the use of generative AI unless explicitly agreed upon with the instructor.'},
#  {'prompt': 'What are the learning outcomes for ECE 8803 ODM?',
#   'response': 'Upon successful completion of ECE 8803 ODM, students should be able to:\nTranslate digital design specifications into concise, synthesizable hardware descriptions using System Verilog.\nEffectively use industry-standard synthesis, place-and-route (SAPR), and verification tools to implement large designs.\nDevelop effective judgment in scoping minimum working examples (MWE) for trailblazing unknown processes.\nEffectively scope and partition design construction, flow development, validation, and test of hardware designs as part of a team effort.\nDesign hardware modules for silicon prototyping, successful testing, characterization, and validation.'},
#  {'prompt': 'Are there required textbooks for ECE 8803 ODM?',
#   'response': "There are no required textbooks for ECE 8803 ODM. The main reference for the class will be the instructor's self-contained course notes. However, the syllabus provides a list of recommended books for students interested in diving deeper into the topics covered."},
#  {'prompt': 'What is the format of the final project in ECE 8803 ODM?',
#   'response': "The final project in ECE 8803 ODM is intended to give students a bird's-eye view of what doing research in online decision making in ML is like. It can take the form of:\nAn in-depth survey of one of the topics covered in the class\nAn application of the algorithms discussed in class on a ML dataset or an engineering application\nA mathematical topic of novel research related to algorithms covered in the class\nStudents can form groups of up to 3 or work alone on this project."},
#  {'prompt': 'What are the prerequisites for ECE 8863 QCDH?',
#   'response': ' The prerequisites for ECE 8863 QCDH include an undergraduate level understanding of quantum mechanics, solid state physics/devices (ECE 3030/3040 level), and linear algebra. Senior undergraduate students are welcome to join the course.'},
#  {'prompt': 'What is the main focus of ECE 8863 QCDH?',
#   'response': 'ECE 8863 QCDH focuses on providing an engineering-oriented treatise of the fundamental building blocks of quantum computers - the quantum computing devices. The course covers the physics of quantum computing, different qubit technologies, full hardware and system level aspects, the state-of-the-art, challenges, and outlook of the quantum computing paradigm.'},
#  {'prompt': 'What are the primary learning outcomes for students taking ECE 8863 QCDH?',
#   'response': 'Upon completion of ECE 8863 QCDH, students should be able to:\nApply their knowledge of engineering to understand the advantages and challenges of different qubit technologies.\nFormulate and solve complex problems in building quantum computer systems by applying principles of quantum physics and technologies.\nUnderstand the state-of-the-art of quantum computing technologies and identify the challenges.\nRecognize the ongoing need to acquire new knowledge by reading and understanding research papers and doing reviews.'},
#  {'prompt': 'How is the grading structured for ECE 8863 QCDH?',
#   'response': 'The grading for ECE 8863 QCDH is structured as follows:\nMid-term (1): 20%\nAssignments (3): 30%\nResearch paper reviews (4): 20%\nFinal exam or research project (report and presentation): 30%'},
#  {'prompt': 'What are the main modules covered in the course outline of ECE 8863 QCDH?',
#   'response': 'ECE 8863 QCDH covers seven main modules:\nQuantum computing in a nutshell\nQuantum computing with trapped ion qubits\nQuantum computing with superconducting qubits\nQuantum computing with semiconductor spin qubits\nOther qubit technologies\nSystem level and hardware aspects\nChallenges, opportunities, outlook and reality check'},
#  {'prompt': 'What textbooks or reference materials are recommended for ECE 8863 QCDH?',
#   'response': 'The course material for ECE 8863 QCDH is derived from various sources, including but not limited to:\nNielsen MA, Chuang I. Quantum computation and quantum information. Cambridge University Press, 2002.\nRieffel, Eleanor G., and Wolfgang H. Polak. Quantum computing: A gentle introduction. MIT Press, 2011.\nFeynman RP. Feynman lectures on computation. CRC Press; 2018 Jul 3.'},
#  {'prompt': ' How does ECE 8863 QCDH address the practical aspects of quantum computing?',
#   'response': 'ECE 8863 QCDH includes discussions on cloud-based quantum computing (IBM and IonQ), reviews of recent status reports, white papers, and road-maps in quantum computing. It also covers key players in quantum computing worldwide and provides an overview of quantum sensing.'},
#  {'prompt': 'What type of assignments can students expect in ECE 8863 QCDH?',
#   'response': ' In ECE 8863 QCDH, students can expect assignments that give an overview of working on typical problems in quantum computing device technologies. These assignments will also familiarize students with simple and basic calculations related to quantum devices operation and design (such as qubit error rates, frequencies, etc.).'},
#  {'prompt': ' How does ECE 8863 QCDH incorporate current research into the curriculum?',
#   'response': ': ECE 8863 QCDH includes paper reviews and discussions of four seminal papers in the area of quantum computing. Additionally, for the final project option, students are expected to solve an open problem and conduct research that can potentially lead to a workshop/conference publication.'},
#  {'prompt': 'Who is the instructor for ECE 8883 HVE?',
#   'response': 'The instructor for ECE 8883 HVE is Dr. Lukas Graber.'},
#  {'prompt': 'When and where are the lectures for ECE 8883 HVE held?',
#   'response': 'ECE 8883 HVE lectures are held on Mondays and Fridays from 10:10-11:00 in van Leer C241, and Wednesdays from 09:55-10:45 in Klaus 2440.'},
#  {'prompt': 'What are the prerequisites for ECE 8883 HVE?',
#   'response': 'The prerequisite for ECE 8883 HVE is ECE 3072.'},
#  {'prompt': 'How is the grading structured for ECE 8883 HVE?',
#   'response': ' The grading for ECE 8883 HVE is structured as follows:\nLab reports: 30%\nProject (presentation + one page summary; in groups of 2): 30%\nMidterm exam: 20%\nFinal exam: 20%'},
#  {'prompt': ' Is there a required textbook for ECE 8883 HVE?',
#   'response': 'Yes, the required textbook for ECE 8883 HVE is Kuffel, Zaengl, Kuffel, "High Voltage Engineering Fundamentals," 2nd ed., Newness, 2000 [ISBN 978-0-7506-3634-6].\n'},
#  {'prompt': 'What are the main topics covered in ECE 8883 HVE?',
#   'response': 'ECE 8883 HVE covers the following main topics:\nGeneration of high voltages\nMeasurement of high voltages\nFundamentals of electrostatic fields and field stress control\nElectrical breakdown in gases and vacuum\nElectrical breakdown in solid and liquid dielectrics\nInsulation test techniques, testing procedures, and insulation coordination\nApplications: Dielectric design of power apparatus'},
#  {'prompt': 'Are there laboratory sessions in ECE 8883 HVE?',
#   'response': 'Yes, ECE 8883 HVE includes laboratory sessions. There will be a total of three laboratory sessions at NEETRAC, 5351 Kennedy Rd, Forest Park, GA 30279. Shuttle bus service or rides from main campus will be provided.\n'},
#  {'prompt': 'What software will be used for computer simulations in ECE 8883 HVE?',
#   'response': 'Computer simulations in ECE 8883 HVE will be based on the scientific computing package COMSOL Multiphysics.'},
#  {'prompt': 'Is there an extra credit opportunity in ECE 8883 HVE?',
#   'response': 'Yes, students in ECE 8883 HVE can earn 2 bonus points (on a scale of 100) towards the final exam by attending 75% of the seminars offered by the IEEE PES Student Chapter.'},
#  {'prompt': 'What is the main focus of ECE 8803 MD?',
#   'response': 'ECE 8803 MD focuses on semiconductor memory technologies, covering device bit-cell structures to memory array design, with an emphasis on industry trends and cutting-edge technologies.'},
#  {'prompt': 'What are the two main parts of the course content in ECE 8803 MD?',
#   'response': ': ECE 8803 MD is divided into two main parts:\nMainstream semiconductor memory technologies that enable various levels in the memory hierarchy (SRAM, DRAM, and FLASH)\nEmerging memory candidates that may change the memory hierarchy (STT-MRAM, PCM, and RRAM) and their new applications'},
#  {'prompt': 'What are the prerequisites for ECE 8803 MD?',
#   'response': 'The prerequisites for ECE 8803 MD are undergraduate-level semiconductor device and digital circuit courses, such as ECE3040 Microelectronic Circuits and ECE3150 VLSI and Advanced Digital Design, or their equivalents.'},
#  {'prompt': 'Are there any recommended graduate-level courses for ECE 8803 MD?',
#   'response': 'While not required, ECE 8803 MD recommends graduate-level semiconductor device and digital circuit courses such as ECE6450 Introduction to Microelectronics Technology and ECE6130 Advanced VLSI Systems, or their equivalents.'},
#  {'prompt': 'How is the grading structured for ECE 8803 MD?',
#   'response': ' The grading for ECE 8803 MD is structured as follows:\nHomework: 50% (5 problem sets, 10% each)\nMidterm Exam: 25%\nFinal Exam: 25%'},
#  {'prompt': 'What tools are required for the homework assignments in ECE 8803 MD?',
#   'response': ' ECE 8803 MD requires pre-knowledge of numerical tools such as MATLAB for homework assignments.'},
#  {'prompt': 'What are students allowed to use during exams in ECE 8803 MD?',
#   'response': 'For both the midterm and final exams in ECE 8803 MD, students are allowed one cheat sheet and a calculator. The exams are closed book and closed lecture notes.'},
#  {'prompt': 'What topics are covered in the SRAM section of ECE 8803 MD?',
#   'response': 'The SRAM section of ECE 8803 MD covers:\n6T cell operation\nNoise margin, stability, scaling issues, and layout\nVariability and reliability issues\nRecent trends, including FinFET technology'},
#  {'prompt': 'What emerging memory technologies are discussed in ECE 8803 MD?',
#   'response': 'ECE 8803 MD discusses emerging memory technologies such as RRAM (Resistive Random Access Memory), PCM (Phase Change Memory), and STT-MRAM (Spin-Transfer Torque Magnetoresistive Random Access Memory).'},
#  {'prompt': 'What new applications of memory technologies are explored in ECE 8803 MD?',
#   'response': 'ECE 8803 MD explores new applications of memory technologies, including non-volatile cache/logic, programmable logic, and hardware accelerators for deep learning.'},
#  {'prompt': 'Who is the instructor for ECE 8873a RWP?',
#   'response': ' The instructor for ECE 8873a RWP is Morris Cohen.'},
#  {'prompt': 'What are the prerequisites for ECE 8873a RWP?',
#   'response': ' The prerequisites for ECE 8873a RWP include an electromagnetics background, with ECE3025 or equivalent required. ECE4350 or 6350 is recommended.\n'},
#  {'prompt': 'When are the lectures for ECE 8873a RWP held?',
#   'response': 'ECE 8873a RWP lectures are held on Mondays and Wednesdays from 3:00-4:15 PM.'},
#  {'prompt': 'How is the grading structured for ECE 8873a RWP?',
#   'response': nan}]

# %%
def format_training_data(training_data):
    data_df = pd.DataFrame(training_data)
    data_df['text'] = data_df[['prompt', 'response']].apply(lambda x: "<|im_start|>user\n"+ str(x['prompt']) + " <|im_end|>\n<|im_start|>assistant\n" + str(x['response']) + "<|im_end|>\n", axis = 1)
    data = Dataset.from_pandas(data_df)
    return data

# %%
data = format_training_data(training_data)

# %%
##### fine tuning ######
peft_config = LoraConfig(
        r=8, lora_alpha=16, lora_dropout=0.05, bias="none", task_type="CAUSAL_LM"
    )

# %%
from peft import LoraConfig, get_peft_model

# %%
?? get_peft_model
# Out:
# Signature:
#  get_peft_model(
#     model: 'PreTrainedModel',
#     peft_config: 'PeftConfig',
#     adapter_name: 'str' = 'default',
#     mixed: 'bool' = False,
#     autocast_adapter_dtype: 'bool' = True,
#     revision: 'Optional[str]' = None,
# ) -> 'PeftModel | PeftMixedModel'
# Source:
# def get_peft_model(
#     model: PreTrainedModel,
#     peft_config: PeftConfig,
#     adapter_name: str = "default",
#     mixed: bool = False,
#     autocast_adapter_dtype: bool = True,
#     revision: Optional[str] = None,
# ) -> PeftModel | PeftMixedModel:
#     """
#     Returns a Peft model object from a model and a config.
#
#     Args:
#         model ([`transformers.PreTrainedModel`]):
#             Model to be wrapped.
#         peft_config ([`PeftConfig`]):
#             Configuration object containing the parameters of the Peft model.
#         adapter_name (`str`, `optional`, defaults to `"default"`):
#             The name of the adapter to be injected, if not provided, the default adapter name is used ("default").
#         mixed (`bool`, `optional`, defaults to `False`):
#             Whether to allow mixing different (compatible) adapter types.
#         autocast_adapter_dtype (`bool`, *optional*):
#             Whether to autocast the adapter dtype. Defaults to `True`. Right now, this will only cast adapter weights
#             using float16 or bfloat16 to float32, as this is typically required for stable training, and only affect
#             select PEFT tuners.
#         revision (`str`, `optional`, defaults to `main`):
#             The revision of the base model. If this isn't set, the saved peft model will load the `main` revision for
#             the base model
#     """
#     model_config = BaseTuner.get_model_config(model)
#     old_name = peft_config.base_model_name_or_path
#     new_name = model.__dict__.get("name_or_path", None)
#     peft_config.base_model_name_or_path = new_name
#
#     if (old_name is not None) and (old_name != new_name):
#         warnings.warn(
#             f"The PEFT config's `base_model_name_or_path` was renamed from '{old_name}' to '{new_name}'. "
#             "Please ensure that the correct base model is loaded when loading this checkpoint."
#         )
#
#     if revision is not None:
#         if peft_config.revision is not None and peft_config.revision != revision:
#             warnings.warn(
#                 f"peft config has already set base model revision to {peft_config.revision}, overwriting with revision {revision}"
#             )
#         peft_config.revision = revision
#
#     if mixed:
#         # note: PeftMixedModel does not support autocast_adapter_dtype, so don't pass it
#         return PeftMixedModel(model, peft_config, adapter_name=adapter_name)
#
#     if peft_config.task_type not in MODEL_TYPE_TO_PEFT_MODEL_MAPPING.keys() and not peft_config.is_prompt_learning:
#         return PeftModel(model, peft_config, adapter_name=adapter_name, autocast_adapter_dtype=autocast_adapter_dtype)
#
#     if peft_config.is_prompt_learning:
#         peft_config = _prepare_prompt_learning_config(peft_config, model_config)
#     return MODEL_TYPE_TO_PEFT_MODEL_MAPPING[peft_config.task_type](
#         model, peft_config, adapter_name=adapter_name, autocast_adapter_dtype=autocast_adapter_dtype
#     )
# File:      ~/.conda/envs/cAI8803-gpu/lib/python3.10/site-packages/peft/mapping.py
# Type:      function

# %%
output_model = "/home/hice1/dbabu6/scratch/model_finetuned_results"

# %%
training_arguments = TrainingArguments(
        output_dir=output_model,
        per_device_train_batch_size=4,
        gradient_accumulation_steps=8,
        optim="paged_adamw_32bit",
        learning_rate=3e-4,
        lr_scheduler_type="cosine",
        save_strategy="epoch",
        logging_steps=10,
        num_train_epochs=8,
        max_steps=250,
        fp16=True,
        push_to_hub=True,
        report_to = "tensorboard"
    )

# %%
trainer = SFTTrainer(
        model=model,
        train_dataset=data,
        peft_config=peft_config,
        dataset_text_field="text",
        args=training_arguments,
        tokenizer=tokenizer,
        packing=False,
        max_seq_length=1024
    )
# Out:
# /home/hice1/dbabu6/.local/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field, max_seq_length. Will not be supported from version '0.13.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /home/hice1/dbabu6/.conda/envs/cAI8803-gpu/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:300: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /home/hice1/dbabu6/.conda/envs/cAI8803-gpu/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:328: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/496 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='3' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  3/250 00:01 < 05:15, 0.78 it/s, Epoch 0.13/17]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=250, training_loss=0.7656039447784424, metrics={'train_runtime': 340.971, 'train_samples_per_second': 23.462, 'train_steps_per_second': 0.733, 'total_flos': 3.865307613649306e+16, 'train_loss': 0.7656039447784424, 'epoch': 16.129032258064516})

# %%
#### running inference #####

# %%
model_id = "Dhanush2210/model_finetuned_results"

# %%
def get_model_and_tokenizer(model_id):
  tokenizer = AutoTokenizer.from_pretrained(model_id)
  tokenizer.pad_token = tokenizer.eos_token
  bnb_config = BitsAndBytesConfig(
      load_in_4bit=True, bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype="float16", bnb_4bit_use_double_quant=True
  )
  model = AutoModelForCausalLM.from_pretrained(
      model_id, quantization_config=bnb_config, device_map="auto"
  )
  model.config.use_cache=False
  model.config.pretraining_tp=1
  return model, tokenizer

# %%
model, tokenizer = get_model_and_tokenizer(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/325 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/673 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/13.6M [00:00<?, ?B/s]

# %%
from transformers import GenerationConfig
from time import perf_counter
def generate_response(user_input):
  prompt = formatted_prompt(user_input)
  # inputs = tokenizer([prompt], return_tensors="pt")
  generation_config = GenerationConfig(penalty_alpha=0.6,do_sample = True,
      top_k=5,temperature=0.2,repetition_penalty=1.2,
      max_new_tokens=80,pad_token_id=tokenizer.eos_token_id
  )
  start_time = perf_counter()
  inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
  outputs = model.generate(**inputs, generation_config=generation_config)
  theresponse = (tokenizer.decode(outputs[0], skip_special_tokens=True))
  print(tokenizer.decode(outputs[0], skip_special_tokens=True))
  output_time = perf_counter() - start_time
  print(f"Time taken for inference: {round(output_time,2)} seconds")

# %%
def formatted_prompt(question)-> str:
    return f"<|im_start|>user\n{question}<|im_end|>\n<|im_start|>assistant:"

# %%
generate_response(user_input= "What is the course's policy on late assignments for ECE 8804 VLSI Design 1?")
# Out:
# <|im_start|>user
# What is the course's policy on late assignments for ECE 8804 VLSI Design 1?<|im_end|>
# <|im_start|>assistant: In ECE 8804 VLSIS, late homeworks will be strictly penalized. The syllabus assumes that all work is done individually unless explicitly stated otherwise.<|im_end|>
# <|im_start|>assistant
# If a valid reason for submitting an assignment late is provided, it will be accepted up to one week after submission deadline or two weeks after opening day, whichever comes first
# Time taken for inference: 3.54 seconds
